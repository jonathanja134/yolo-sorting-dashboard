# %% [markdown]
# # TO DO #

# %%
alow display log on website

# %%
do start everything in one line of code

# %%
display error in the righht section

# %%
display the vote with the different model detected
-display it on the log for continous iinprovement

# %%
look for hotspot the PI itself to combine with ethernet connection

# %%
arduino-cli compile --fqbn arduino:avr:mega Arduino_test/ && arduino-cli upload -p /dev/ttyACM0 --fqbn arduino:avr:mega Arduino_test/

# %% [markdown]
# # TO DO #

# %%
from IPython.display import Markdown, display
display(Markdown(f"""```mermaid
graph TD
    A[Arduino.ino] --> B[yolo_detect_ncnn_headless.py]
    B --> C[ProgramManager]
    C --> D[Buffer.py]
    C --> E[config.py]
    C --> F[ErrorManager.py]
    C --> G[KeyboardSimulation.py]
    C --> H[serialManager.py]
    C --> I[socketManager.py]"""))
# Out:
# ```mermaid
# graph TD
#     A[Arduino.ino] --> B[yolo_detect_ncnn_headless.py]
#     B --> C[ProgramManager]
#     C --> D[Buffer.py]
#     C --> E[config.py]
#     C --> F[ErrorManager.py]
#     C --> G[KeyboardSimulation.py]
#     C --> H[serialManager.py]
#     C --> I[socketManager.py]

# %% [markdown]
# ## ARDUINO
# | **Arduino/Arduino.ino**
#
# controls motors (conveyors)
# controls 4 servos (sorting gates)
# reads sensors (proximity / detection)
# handles START/STOP button
# enforces safety checks (SYSTEM running or not)
# sends serial messages to Pi:
# SERVO:OPEN
# SERVO:CLOSED_OK
# SENSOR:TRIGGERED
# ERR:*
# ACK:SYSTEM:*
